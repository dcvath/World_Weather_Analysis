# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['jalu', 'hualmay', 'hithadhoo', 'mount isa', 'mataura', 'zhigansk', 'hilo', 'hobart', 'hobyo', 'jamestown'] Generate 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Weather Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jalu
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | mount isa
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | hobyo
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | kurkino
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | salihorsk
# Processing Record 23 of Set 1 | buta
# Processing Record 24 of Set 1 | tripoli
# Processing Record 25 of Set 1 | krumovgrad
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | tiarei
# Processing Record 30 of Set 1 | ayorou
# Processing Record 31 of Set 1 | upata
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | karacakoy
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | balikpapan
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | ginda
# Processing Record 42 of Set 1 | mweka
# Processing Record 43 of Set 1 | haines junction
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | robertsport
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | parana
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 2 | shingu
# Processing Record 4 of Set 2 | matagami
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | champerico
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | ust-koksa
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | chapais
# Processing Record 14 of Set 2 | richards bay
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | lac du bonnet
# Processing Record 19 of Set 2 | krasnoye
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | jaguaquara
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | chulman
# Processing Record 27 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | tukrah
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | yei
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | port hueneme
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | muros
# Processing Record 37 of Set 2 | porto belo
# Processing Record 38 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 2 | yura
# Processing Record 40 of Set 2 | hoopstad
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | orchard homes
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | dunedin
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | kargasok
# Processing Record 48 of Set 2 | panzhihua
# Processing Record 49 of Set 2 | upington
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | kampot
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | qaqortoq
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | ylivieska
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | samana
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | biak
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | puerto escondido
# Processing Record 20 of Set 3 | kyotera
# Processing Record 21 of Set 3 | margate
# Processing Record 22 of Set 3 | curuca
# Processing Record 23 of Set 3 | jiaonan
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | broome
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | bereda
# Processing Record 29 of Set 3 | vestmannaeyjar
# Processing Record 30 of Set 3 | le pont-de-claix
# Processing Record 31 of Set 3 | cabo san lucas
# Processing Record 32 of Set 3 | lata
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | ornskoldsvik
# Processing Record 35 of Set 3 | aklavik
# Processing Record 36 of Set 3 | lokosovo
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | miraflores
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | sinnamary
# Processing Record 42 of Set 3 | mayo
# Processing Record 43 of Set 3 | dieppe
# Processing Record 44 of Set 3 | teya
# Processing Record 45 of Set 3 | antofagasta
# Processing Record 46 of Set 3 | kentau
# Processing Record 47 of Set 3 | spilimbergo
# Processing Record 48 of Set 3 | nemuro
# Processing Record 49 of Set 3 | goderich
# Processing Record 50 of Set 3 | at-bashi
# Processing Record 1 of Set 4 | nadadores
# Processing Record 2 of Set 4 | tazovskiy
# Processing Record 3 of Set 4 | yeniseysk
# Processing Record 4 of Set 4 | paita
# Processing Record 5 of Set 4 | solec kujawski
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | alyangula
# Processing Record 8 of Set 4 | parry sound
# Processing Record 9 of Set 4 | coxim
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | abu samrah
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | soc trang
# Processing Record 16 of Set 4 | revelganj
# Processing Record 17 of Set 4 | bogdanita
# Processing Record 18 of Set 4 | alcudia
# Processing Record 19 of Set 4 | ixtapa
# Processing Record 20 of Set 4 | camana
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | shiringushi
# Processing Record 24 of Set 4 | labuhan
# Processing Record 25 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 4 | camacha
# Processing Record 27 of Set 4 | kwidzyn
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 4 | sayyan
# Processing Record 31 of Set 4 | yulara
# Processing Record 32 of Set 4 | olafsvik
# Processing Record 33 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 4 | tortosa
# Processing Record 36 of Set 4 | coos bay
# Processing Record 37 of Set 4 | souillac
# Processing Record 38 of Set 4 | veraval
# Processing Record 39 of Set 4 | puerto del rosario
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | barcelona
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | coihaique
# Processing Record 44 of Set 4 | rudbar
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | auki
# Processing Record 50 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | araguacu
# Processing Record 4 of Set 5 | taraz
# Processing Record 5 of Set 5 | high prairie
# Processing Record 6 of Set 5 | fomboni
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | tautira
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | bethel
# Processing Record 11 of Set 5 | peace river
# Processing Record 12 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 5 | tasiilaq
# Processing Record 14 of Set 5 | zhezkazgan
# Processing Record 15 of Set 5 | jumla
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | benton harbor
# Processing Record 19 of Set 5 | santa marta
# Processing Record 20 of Set 5 | ranfurly
# Processing Record 21 of Set 5 | shimoda
# Processing Record 22 of Set 5 | chulym
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | ati
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | makakilo city
# Processing Record 27 of Set 5 | san fernando
# Processing Record 28 of Set 5 | nylstroom
# City not found. Skipping...
# Processing Record 29 of Set 5 | yar-sale
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | chumikan
# Processing Record 32 of Set 5 | liangxiang
# Processing Record 33 of Set 5 | kedrovyy
# Processing Record 34 of Set 5 | cayenne
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | ketchikan
# Processing Record 37 of Set 5 | gizo
# Processing Record 38 of Set 5 | mahon
# Processing Record 39 of Set 5 | ayr
# Processing Record 40 of Set 5 | semnan
# Processing Record 41 of Set 5 | buncrana
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | burns lake
# Processing Record 44 of Set 5 | huescar
# Processing Record 45 of Set 5 | mandalgovi
# Processing Record 46 of Set 5 | banda aceh
# Processing Record 47 of Set 5 | bahia blanca
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 5 | dikson
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | klobuck
# Processing Record 3 of Set 6 | lensk
# Processing Record 4 of Set 6 | alexandria
# Processing Record 5 of Set 6 | pochutla
# Processing Record 6 of Set 6 | oranjemund
# Processing Record 7 of Set 6 | portland
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 6 | guiglo
# Processing Record 11 of Set 6 | new norfolk
# Processing Record 12 of Set 6 | itarema
# Processing Record 13 of Set 6 | elverum
# Processing Record 14 of Set 6 | kushmurun
# Processing Record 15 of Set 6 | plettenberg bay
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | northam
# Processing Record 18 of Set 6 | kununurra
# Processing Record 19 of Set 6 | cherskiy
# Processing Record 20 of Set 6 | adrar
# Processing Record 21 of Set 6 | ahipara
# Processing Record 22 of Set 6 | vastervik
# City not found. Skipping...
# Processing Record 23 of Set 6 | amot
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | sakakah
# Processing Record 26 of Set 6 | seymchan
# Processing Record 27 of Set 6 | irondequoit
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | chicama
# Processing Record 30 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 6 | lufilufi
# Processing Record 32 of Set 6 | redmond
# Processing Record 33 of Set 6 | sikasso
# Processing Record 34 of Set 6 | kralendijk
# Processing Record 35 of Set 6 | vuktyl
# Processing Record 36 of Set 6 | leningradskiy
# Processing Record 37 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | semporna
# Processing Record 41 of Set 6 | pisco
# Processing Record 42 of Set 6 | manta
# Processing Record 43 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 6 | chabahar
# Processing Record 45 of Set 6 | kapit
# Processing Record 46 of Set 6 | bulqize
# Processing Record 47 of Set 6 | slave lake
# Processing Record 48 of Set 6 | drayton valley
# Processing Record 49 of Set 6 | salalah
# Processing Record 50 of Set 6 | bosaso
# Processing Record 1 of Set 7 | necochea
# Processing Record 2 of Set 7 | hailar
# Processing Record 3 of Set 7 | shelburne
# Processing Record 4 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 7 | kokopo
# Processing Record 6 of Set 7 | guiyang
# Processing Record 7 of Set 7 | nimaparha
# Processing Record 8 of Set 7 | baoqing
# Processing Record 9 of Set 7 | royal leamington spa
# Processing Record 10 of Set 7 | grand baie
# Processing Record 11 of Set 7 | doha
# Processing Record 12 of Set 7 | bilma
# Processing Record 13 of Set 7 | sabha
# Processing Record 14 of Set 7 | isangel
# Processing Record 15 of Set 7 | bulalacao
# Processing Record 16 of Set 7 | khani
# Processing Record 17 of Set 7 | wadi maliz
# Processing Record 18 of Set 7 | krasnyy kut
# Processing Record 19 of Set 7 | yaring
# Processing Record 20 of Set 7 | kapoeta
# Processing Record 21 of Set 7 | boguchany
# Processing Record 22 of Set 7 | amahai
# Processing Record 23 of Set 7 | ambon
# Processing Record 24 of Set 7 | manjacaze
# Processing Record 25 of Set 7 | cairns
# Processing Record 26 of Set 7 | durgapur
# Processing Record 27 of Set 7 | constitucion
# Processing Record 28 of Set 7 | chalchihuites
# Processing Record 29 of Set 7 | tocantinopolis
# City not found. Skipping...
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | ucluelet
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | tucuman
# Processing Record 34 of Set 7 | arcata
# Processing Record 35 of Set 7 | najran
# Processing Record 36 of Set 7 | vanderhoof
# Processing Record 37 of Set 7 | troitsko-pechorsk
# Processing Record 38 of Set 7 | wote
# Processing Record 39 of Set 7 | ballina
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | ambanja
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | la serena
# Processing Record 44 of Set 7 | dzilam gonzalez
# Processing Record 45 of Set 7 | jacareacanga
# Processing Record 46 of Set 7 | narsaq
# Processing Record 47 of Set 7 | tommot
# Processing Record 48 of Set 7 | puerto plata
# Processing Record 49 of Set 7 | krasnoyarka
# Processing Record 50 of Set 7 | buala
# Processing Record 1 of Set 8 | linhares
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | mersing
# Processing Record 4 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 8 | kotelnich
# Processing Record 6 of Set 8 | oussouye
# Processing Record 7 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 8 | kaeo
# Processing Record 9 of Set 8 | nome
# Processing Record 10 of Set 8 | floriano
# Processing Record 11 of Set 8 | svetlogorsk
# Processing Record 12 of Set 8 | sault sainte marie
# Processing Record 13 of Set 8 | izvestkovyy
# Processing Record 14 of Set 8 | malinao
# Processing Record 15 of Set 8 | chavakkad
# Processing Record 16 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 8 | caetite
# Processing Record 18 of Set 8 | springbok
# Processing Record 19 of Set 8 | aykhal
# Processing Record 20 of Set 8 | sironj
# Processing Record 21 of Set 8 | monrovia
# Processing Record 22 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 8 | touros
# Processing Record 24 of Set 8 | caravelas
# Processing Record 25 of Set 8 | agirish
# Processing Record 26 of Set 8 | aquiraz
# Processing Record 27 of Set 8 | cape coast
# Processing Record 28 of Set 8 | hervey bay
# Processing Record 29 of Set 8 | bassila
# Processing Record 30 of Set 8 | rodrigues alves
# Processing Record 31 of Set 8 | acapulco
# Processing Record 32 of Set 8 | teknaf
# Processing Record 33 of Set 8 | hede
# Processing Record 34 of Set 8 | tshela
# Processing Record 35 of Set 8 | punta umbria
# Processing Record 36 of Set 8 | arman
# Processing Record 37 of Set 8 | ilulissat
# Processing Record 38 of Set 8 | chokurdakh
# Processing Record 39 of Set 8 | bac lieu
# Processing Record 40 of Set 8 | palembang
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | shaoguan
# Processing Record 43 of Set 8 | vigia
# Processing Record 44 of Set 8 | matara
# Processing Record 45 of Set 8 | birao
# Processing Record 46 of Set 8 | kurilsk
# Processing Record 47 of Set 8 | maniitsoq
# Processing Record 48 of Set 8 | mount gambier
# Processing Record 49 of Set 8 | isiro
# Processing Record 50 of Set 8 | puerto baquerizo moreno
# Processing Record 1 of Set 9 | mamakan
# Processing Record 2 of Set 9 | harper
# Processing Record 3 of Set 9 | sur
# Processing Record 4 of Set 9 | sirjan
# Processing Record 5 of Set 9 | bereznik
# Processing Record 6 of Set 9 | east london
# Processing Record 7 of Set 9 | nanortalik
# Processing Record 8 of Set 9 | invermere
# Processing Record 9 of Set 9 | geraldton
# Processing Record 10 of Set 9 | klaksvik
# Processing Record 11 of Set 9 | berdigestyakh
# Processing Record 12 of Set 9 | yingcheng
# Processing Record 13 of Set 9 | turayf
# Processing Record 14 of Set 9 | sinop
# Processing Record 15 of Set 9 | casteltermini
# Processing Record 16 of Set 9 | ouadda
# Processing Record 17 of Set 9 | honningsvag
# Processing Record 18 of Set 9 | abalak
# Processing Record 19 of Set 9 | macapa
# Processing Record 20 of Set 9 | alice springs
# Processing Record 21 of Set 9 | roma
# Processing Record 22 of Set 9 | havelock
# Processing Record 23 of Set 9 | bafra
# Processing Record 24 of Set 9 | daru
# Processing Record 25 of Set 9 | mehamn
# Processing Record 26 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 27 of Set 9 | marzuq
# Processing Record 28 of Set 9 | cidreira
# Processing Record 29 of Set 9 | caronport
# Processing Record 30 of Set 9 | bakchar
# Processing Record 31 of Set 9 | shahr-e babak
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 9 | pachino
# Processing Record 35 of Set 9 | havre-saint-pierre
# Processing Record 36 of Set 9 | nelson bay
# Processing Record 37 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 9 | xining
# Processing Record 39 of Set 9 | opuwo
# Processing Record 40 of Set 9 | marystown
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 9 | sao gabriel da cachoeira
# Processing Record 44 of Set 9 | steamboat springs
# Processing Record 45 of Set 9 | whitehorse
# Processing Record 46 of Set 9 | vao
# Processing Record 47 of Set 9 | tawang
# Processing Record 48 of Set 9 | grande-riviere
# City not found. Skipping...
# Processing Record 49 of Set 9 | astana
# Processing Record 50 of Set 9 | machinga
# Processing Record 1 of Set 10 | ruteng
# Processing Record 2 of Set 10 | miguel hidalgo
# Processing Record 3 of Set 10 | awjilah
# Processing Record 4 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 10 | tieling
# Processing Record 6 of Set 10 | bilibino
# Processing Record 7 of Set 10 | poya
# Processing Record 8 of Set 10 | inyonga
# Processing Record 9 of Set 10 | zhenhai
# Processing Record 10 of Set 10 | corinto
# Processing Record 11 of Set 10 | nambucca heads
# Processing Record 12 of Set 10 | sobolevo
# Processing Record 13 of Set 10 | togur
# Processing Record 14 of Set 10 | illela
# Processing Record 15 of Set 10 | hutchinson
# Processing Record 16 of Set 10 | pinsk
# Processing Record 17 of Set 10 | galveston
# Processing Record 18 of Set 10 | laguna
# Processing Record 19 of Set 10 | misratah
# Processing Record 20 of Set 10 | faya
# Processing Record 21 of Set 10 | summerside
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | vardo
# Processing Record 24 of Set 10 | tezu
# Processing Record 25 of Set 10 | svetlaya
# Processing Record 26 of Set 10 | severo-kurilsk
# Processing Record 27 of Set 10 | coquimbo
# Processing Record 28 of Set 10 | ust-nera
# Processing Record 29 of Set 10 | biscarrosse
# Processing Record 30 of Set 10 | mezen
# Processing Record 31 of Set 10 | liwale
# Processing Record 32 of Set 10 | kahului
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | kebemer
# City not found. Skipping...
# Processing Record 35 of Set 10 | encruzilhada do sul
# Processing Record 36 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 10 | caldwell
# Processing Record 38 of Set 10 | watsa
# Processing Record 39 of Set 10 | parabel
# Processing Record 40 of Set 10 | sovetskaya gavan
# Processing Record 41 of Set 10 | temerloh
# Processing Record 42 of Set 10 | cabinda
# Processing Record 43 of Set 10 | yarkovo
# Processing Record 44 of Set 10 | kassala
# Processing Record 45 of Set 10 | shahdadkot
# Processing Record 46 of Set 10 | norton
# Processing Record 47 of Set 10 | kerman
# Processing Record 48 of Set 10 | hofn
# Processing Record 49 of Set 10 | talnakh
# Processing Record 50 of Set 10 | tura
# Processing Record 1 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 11 | labrea
# Processing Record 3 of Set 11 | guarapari
# Processing Record 4 of Set 11 | fengrun
# Processing Record 5 of Set 11 | guanay
# Processing Record 6 of Set 11 | icod de los vinos
# Processing Record 7 of Set 11 | san francisco
# Processing Record 8 of Set 11 | indianola
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | marsh harbour
# Processing Record 12 of Set 11 | carmen
# Processing Record 13 of Set 11 | toronto
# Processing Record 14 of Set 11 | gayny
# Processing Record 15 of Set 11 | ciudad bolivar
# Processing Record 16 of Set 11 | camocim
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | charlestown
# Processing Record 19 of Set 11 | puerto maldonado
# Processing Record 20 of Set 11 | eberbach
# Processing Record 21 of Set 11 | kommunar
# Processing Record 22 of Set 11 | sosenskiy
# Processing Record 23 of Set 11 | general pico
# Processing Record 24 of Set 11 | palauig
# Processing Record 25 of Set 11 | cienaga
# Processing Record 26 of Set 11 | uyuni
# Processing Record 27 of Set 11 | saint-georges
# Processing Record 28 of Set 11 | mareeba
# Processing Record 29 of Set 11 | luganville
# Processing Record 30 of Set 11 | tilichiki
# Processing Record 31 of Set 11 | dumas
# Processing Record 32 of Set 11 | vorchdorf
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | arlit
# Processing Record 35 of Set 11 | bonavista
# Processing Record 36 of Set 11 | port hedland
# Processing Record 37 of Set 11 | sale
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | brae
# Processing Record 40 of Set 11 | atasu
# Processing Record 41 of Set 11 | pangnirtung
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | narragansett
# Processing Record 44 of Set 11 | husavik
# Processing Record 45 of Set 11 | srednekolymsk
# Processing Record 46 of Set 11 | binga
# Processing Record 47 of Set 11 | ekibastuz
# Processing Record 48 of Set 11 | belle fourche
# Processing Record 49 of Set 11 | zharkent
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 12 | mingguang
# Processing Record 3 of Set 12 | barra do garcas
# Processing Record 4 of Set 12 | saint-pierre
# Processing Record 5 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 12 | srisailam
# Processing Record 7 of Set 12 | morondava
# Processing Record 8 of Set 12 | cutro
# Processing Record 9 of Set 12 | carutapera
# Processing Record 10 of Set 12 | guekedou
# City not found. Skipping...
# Processing Record 11 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 12 | port shepstone
# Processing Record 13 of Set 12 | verkhniy avzyan
# Processing Record 14 of Set 12 | weligama
# Processing Record 15 of Set 12 | copiapo
# Processing Record 16 of Set 12 | santa isabel
# Processing Record 17 of Set 12 | hovd
# Processing Record 18 of Set 12 | madang
# Processing Record 19 of Set 12 | tevriz
# Processing Record 20 of Set 12 | dwarka
# Processing Record 21 of Set 12 | riverton
# Processing Record 22 of Set 12 | qiongshan
# Processing Record 23 of Set 12 | iqaluit
# Processing Record 24 of Set 12 | monte escobedo
# Processing Record 25 of Set 12 | damghan
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | atar
# Processing Record 28 of Set 12 | wajima
# Processing Record 29 of Set 12 | noshiro
# Processing Record 30 of Set 12 | ramban
# Processing Record 31 of Set 12 | vytegra
# Processing Record 32 of Set 12 | hambantota
# Processing Record 33 of Set 12 | wanning
# Processing Record 34 of Set 12 | perth
# Processing Record 35 of Set 12 | altoona
# Processing Record 36 of Set 12 | umm kaddadah
# Processing Record 37 of Set 12 | tarauaca
# Processing Record 38 of Set 12 | san cristobal
# Processing Record 39 of Set 12 | morehead
# Processing Record 40 of Set 12 | aransas pass
# Processing Record 41 of Set 12 | makokou
# Processing Record 42 of Set 12 | sturgis
# Processing Record 43 of Set 12 | batagay
# Processing Record 44 of Set 12 | flinders
# Processing Record 45 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 46 of Set 12 | aktanysh
# Processing Record 47 of Set 12 | kindersley
# Processing Record 48 of Set 12 | severo-yeniseyskiy
# Processing Record 49 of Set 12 | staraya poltavka
# Processing Record 50 of Set 12 | revadanda
# Processing Record 1 of Set 13 | shahpur
# Processing Record 2 of Set 13 | atlantic city
# Processing Record 3 of Set 13 | petrolandia
# City not found. Skipping...
# Processing Record 4 of Set 13 | amarante do maranhao
# Processing Record 5 of Set 13 | mitsamiouli
# Processing Record 6 of Set 13 | pangkalanbuun
# Processing Record 7 of Set 13 | ruston
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | the valley
# Processing Record 10 of Set 13 | dukat
# Processing Record 11 of Set 13 | talara
# Processing Record 12 of Set 13 | porangatu
# Processing Record 13 of Set 13 | ballyshannon
# Processing Record 14 of Set 13 | bronnoysund
# Processing Record 15 of Set 13 | suraabad
# Processing Record 16 of Set 13 | samarai
# Processing Record 17 of Set 13 | waingapu
# Processing Record 18 of Set 13 | rumonge
# Processing Record 19 of Set 13 | tuatapere
# Processing Record 20 of Set 13 | durusu
# Processing Record 21 of Set 13 | villa carlos paz
# Processing Record 22 of Set 13 | mongu
# Processing Record 23 of Set 13 | liverpool
# Processing Record 24 of Set 13 | shamgarh
# Processing Record 25 of Set 13 | brasileia
# Processing Record 26 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 13 | kohima
# Processing Record 28 of Set 13 | elko
# Processing Record 29 of Set 13 | jijiga
# Processing Record 30 of Set 13 | evensk
# Processing Record 31 of Set 13 | burica
# City not found. Skipping...
# Processing Record 32 of Set 13 | pitimbu
# Processing Record 33 of Set 13 | asyut
# Processing Record 34 of Set 13 | yining
# Processing Record 35 of Set 13 | alekseyevsk
# Processing Record 36 of Set 13 | mount hagen
# Processing Record 37 of Set 13 | saint-augustin
# Processing Record 38 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 13 | asfi
# Processing Record 42 of Set 13 | mosjoen
# Processing Record 43 of Set 13 | hamilton
# Processing Record 44 of Set 13 | bijie
# Processing Record 45 of Set 13 | quixeramobim
# Processing Record 46 of Set 13 | baghdad
# Processing Record 47 of Set 13 | peterhead
# Processing Record 48 of Set 13 | jevargi
# Processing Record 49 of Set 13 | severnyy
# Processing Record 50 of Set 13 | buraydah
# Processing Record 1 of Set 14 | devrek
# Processing Record 2 of Set 14 | jeannette
# Processing Record 3 of Set 14 | kiskunmajsa
# Processing Record 4 of Set 14 | bobo dioulasso
# Processing Record 5 of Set 14 | abu zabad
# Processing Record 6 of Set 14 | besikduzu
# Processing Record 7 of Set 14 | dandong
# Processing Record 8 of Set 14 | shirokiy
# Processing Record 9 of Set 14 | thinadhoo
# Processing Record 10 of Set 14 | fredericksburg
# Processing Record 11 of Set 14 | buin
# Processing Record 12 of Set 14 | isla aguada
# Processing Record 13 of Set 14 | kashi
# Processing Record 14 of Set 14 | japura
# Processing Record 15 of Set 14 | nchelenge
# Processing Record 16 of Set 14 | monopoli
# Processing Record 17 of Set 14 | staraya toropa
# Processing Record 18 of Set 14 | viedma
# Processing Record 19 of Set 14 | heihe
# Processing Record 20 of Set 14 | port said
# Processing Record 21 of Set 14 | ndioum
# Processing Record 22 of Set 14 | burevestnik
# Processing Record 23 of Set 14 | sao jose da coroa grande
# Processing Record 24 of Set 14 | podosinovets
# Processing Record 25 of Set 14 | kenai
# Processing Record 26 of Set 14 | comodoro rivadavia
# Processing Record 27 of Set 14 | rincon
# Processing Record 28 of Set 14 | tiksi
# Processing Record 29 of Set 14 | constantine
# Processing Record 30 of Set 14 | san ramon
# Processing Record 31 of Set 14 | strezhevoy
# Processing Record 32 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 14 | flagstaff
# Processing Record 34 of Set 14 | college
# Processing Record 35 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 14 | paamiut
# Processing Record 37 of Set 14 | ternate
# Processing Record 38 of Set 14 | great bend
# Processing Record 39 of Set 14 | vernon
# Processing Record 40 of Set 14 | kawalu
# Processing Record 41 of Set 14 | bouillante
# Processing Record 42 of Set 14 | mandera
# Processing Record 43 of Set 14 | konstantinovka
# Processing Record 44 of Set 14 | outjo
# Processing Record 45 of Set 14 | qasigiannguit
# Processing Record 46 of Set 14 | coahuayana
# Processing Record 47 of Set 14 | qostanay
# Processing Record 48 of Set 14 | banjarmasin
# Processing Record 49 of Set 14 | sangar
# Processing Record 50 of Set 14 | pundaguitan
# Processing Record 1 of Set 15 | lerwick
# Processing Record 2 of Set 15 | mackay
# Processing Record 3 of Set 15 | hami
# Processing Record 4 of Set 15 | winnemucca
# Processing Record 5 of Set 15 | boyolangu
# Processing Record 6 of Set 15 | ygatimi
# Processing Record 7 of Set 15 | andarab
# City not found. Skipping...
# Processing Record 8 of Set 15 | ronne
# Processing Record 9 of Set 15 | poum
# Processing Record 10 of Set 15 | west bay
# Processing Record 11 of Set 15 | ukiah
# Processing Record 12 of Set 15 | pedra branca
# Processing Record 13 of Set 15 | erzin
# Processing Record 14 of Set 15 | churapcha
# Processing Record 15 of Set 15 | elizabeth city
# Processing Record 16 of Set 15 | ulladulla
# Processing Record 17 of Set 15 | san angelo
# Processing Record 18 of Set 15 | taoudenni
# Processing Record 19 of Set 15 | sakrand
# Processing Record 20 of Set 15 | noyabrsk
# Processing Record 21 of Set 15 | kosonsoy
# Processing Record 22 of Set 15 | yaviza
# Processing Record 23 of Set 15 | hornepayne
# Processing Record 24 of Set 15 | cadereyta
# Processing Record 25 of Set 15 | fukue
# Processing Record 26 of Set 15 | aasiaat
# Processing Record 27 of Set 15 | tashigang
# Processing Record 28 of Set 15 | nampa
# Processing Record 29 of Set 15 | katima mulilo
# Processing Record 30 of Set 15 | sweetwater
# Processing Record 31 of Set 15 | takoradi
# Processing Record 32 of Set 15 | innisfail
# Processing Record 33 of Set 15 | basco
# Processing Record 34 of Set 15 | santa fe
# Processing Record 35 of Set 15 | port augusta
# Processing Record 36 of Set 15 | tessalit
# Processing Record 37 of Set 15 | zaltan
# Processing Record 38 of Set 15 | vostok
# Processing Record 39 of Set 15 | zeya
# Processing Record 40 of Set 15 | namestovo
# Processing Record 41 of Set 15 | khandbari
# Processing Record 42 of Set 15 | saint anthony
# Processing Record 43 of Set 15 | bathsheba
# Processing Record 44 of Set 15 | pespire
# Processing Record 45 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 15 | porlamar
# Processing Record 47 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 15 | salina cruz
# Processing Record 49 of Set 15 | thio
# Processing Record 50 of Set 15 | korla
# Processing Record 1 of Set 16 | melo
# Processing Record 2 of Set 16 | orbetello
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 694

# %%
#Add to new DataFrame
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0           jalu      LY  2021-08-02 00:54:14  29.0331   21.5482     83.44
# 1        hualmay      PE  2021-08-02 00:54:15 -11.0964  -77.6139     63.77
# 2      hithadhoo      MV  2021-08-02 00:49:34  -0.6000   73.0833     81.32
# 3      mount isa      AU  2021-08-02 00:54:02 -20.7333  139.5000     85.77
# 4        mataura      NZ  2021-08-02 00:54:16 -46.1927  168.8643     45.48
# ..           ...     ...                  ...      ...       ...       ...
# 689  salina cruz      MX  2021-08-02 00:58:14  16.1667  -95.2000     86.54
# 690         thio      NC  2021-08-02 00:58:15 -21.6167  166.2167     71.56
# 691        korla      CN  2021-08-02 00:58:15  41.7597   86.1469     77.27
# 692         melo      UY  2021-08-02 00:58:15 -32.3667  -54.1833     45.77
# 693    orbetello      IT  2021-08-02 00:58:16  42.4408   11.2196     71.80
#
#      Humidity  Cloudiness  Wind Speed Weather Description
# 0          36           0        9.06           clear sky
# 1          83          17       10.78          few clouds
# 2          72          85        6.42     overcast clouds
# 3          32          40        8.05    scattered clouds
# 4          83         100        2.10     overcast clouds
# ..        ...         ...         ...                 ...
# 689        62          99       12.91     overcast clouds
# 690        48           0        3.13           clear sky
# 691        15          98        2.42     overcast clouds
# 692        88           0        5.10           clear sky
# 693        66          64        8.34       broken clouds
#
# [694 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
challenge_city_data_df.to_csv(output_data_file, index_label="City_ID")
